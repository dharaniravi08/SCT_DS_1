# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("C:/Users/P3Fusion/Downloads/archi/tested.csv")
print(data.head())
age_data = data['Age'].dropna()
plt.figure(figsize=(10, 6))
sns.histplot(age_data, bins=20, kde=True, color='skyblue')
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 data = pd.read_csv("C:/Users/P3Fusion/Downloads/archi/tested.csv")
#       5 print(data.head())
#       6 age_data = data['Age'].dropna()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
population_data = pd.read_csv("C:/Users/P3Fusion/Downloads/archive/state_pop_by_age_gender.csv")
print(population_data.head(100))
plt.figure(figsize=(12, 6))
sns.countplot(data=population_data, x=', color='orange')
plt.title('Age Distribution in the World Population')
plt.xlabel('age')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#       state state_abbr gender_group age_group  population
# 0   Alabama         AL       Female       <18      536918
# 1   Alabama         AL       Female       18+     1979977
# 2   Alabama         AL       Female       All     2516895
# 3   Alabama         AL         Male       <18      559458
# 4   Alabama         AL         Male       18+     1799897
# ..      ...        ...          ...       ...         ...
# 95   Hawaii         HI         Male       All      713260
# 96   Hawaii         HI         Both       <18      304638
# 97   Hawaii         HI         Both       18+     1117456
# 98   Hawaii         HI         Both       All     1422094
# 99    Idaho         ID       Female       <18      215455
#
# [100 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
population_data = pd.read_csv("C:/Users/P3Fusion/Downloads/archive (3)/World Marriage Dataset.csv")
print(population_data.head())
plt.figure(figsize=(12, 6))
sns.countplot(data=population_data, x='Sex', color='orange')
plt.title('Age Distribution in the World Population')
plt.xlabel('age')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout() 
plt.show()
# Out:
#    Sr.No.      Country AgeGroup  Sex MaritalStatus DataProcess  \
# 0       1  Afghanistan  [15-19]  Man      Divorced      Survey
# 1       2  Afghanistan  [20-24]  Man      Divorced      Survey
# 2       3  Afghanistan  [25-29]  Man      Divorced      Survey
# 3       4  Afghanistan  [30-34]  Man      Divorced      Survey
# 4       5  Afghanistan  [35-39]  Man      Divorced      Survey
#
#    Data Collection (Start Year)  Data Collection (End Year)  \
# 0                          1972                        1974
# 1                          1972                        1974
# 2                          1972                        1974
# 3                          1972                        1974
# 4                          1972                        1974
#
#            Data Source
# 0  National statistics
# 1  National statistics
# 2  National statistics
# 3  National statistics
# 4  National statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
population_data = pd.read_csv("C:/Users/P3Fusion/Downloads/archive (3)/World Marriage Dataset.csv")
print(population_data.head())
plt.figure(figsize=(12, 6))
sns.countplot(data=population_data, x='gender', color='orange')
plt.title('gender Distribution in the World Population')
plt.xlabel('gender')
plt.ylabel('population')
plt.grid(True)
plt.tight_layout() 
plt.show()
# Out:
#    Sr.No.      Country AgeGroup gender MaritalStatus DataProcess  \
# 0       1  Afghanistan  [15-19]    Man      Divorced      Survey
# 1       2  Afghanistan  [20-24]    Man      Divorced      Survey
# 2       3  Afghanistan  [25-29]    Man      Divorced      Survey
# 3       4  Afghanistan  [30-34]    Man      Divorced      Survey
# 4       5  Afghanistan  [35-39]    Man      Divorced      Survey
#
#    Data Collection (Start Year)  Data Collection (End Year)  \
# 0                          1972                        1974
# 1                          1972                        1974
# 2                          1972                        1974
# 3                          1972                        1974
# 4                          1972                        1974
#
#            Data Source
# 0  National statistics
# 1  National statistics
# 2  National statistics
# 3  National statistics
# 4  National statistics
